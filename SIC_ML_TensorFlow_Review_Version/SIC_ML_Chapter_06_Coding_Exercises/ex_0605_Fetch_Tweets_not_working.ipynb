# %% [markdown]
# ## Coding Exercise #0605

# %%
# Install Tweepy version 4 for access to the Twitter API v2.
# !pip install tweepy==4
# Out:
# Collecting tweepy==4
#   Downloading tweepy-4.0.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.11.1 in /usr/local/lib/python3.10/dist-packages (from tweepy==4) (2.31.0)
# Requirement already satisfied: requests-oauthlib<2,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tweepy==4) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.11.1->tweepy==4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.11.1->tweepy==4) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.11.1->tweepy==4) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.11.1->tweepy==4) (2024.6.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib<2,>=1.0.0->tweepy==4) (3.2.2)
# Installing collected packages: tweepy
#   Attempting uninstall: tweepy
#     Found existing installation: tweepy 4.14.0
#     Uninstalling tweepy-4.14.0:
#       Successfully uninstalled tweepy-4.14.0
# Successfully installed tweepy-4.0.0

# %%
import tweepy
import re
import os
import pickle
import nltk
from nltk.corpus import stopwords
from tweepy import OAuthHandler

# %%
# %%time
# You should download the NLTK data once.
# It can be a bit time consuming.
# nltk.download()
# We download just what we need.
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# CPU times: user 424 ms, sys: 119 ms, total: 543 ms
# Wall time: 818 ms
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ### 1. Fetch tweets
# More information can be found [here](https://docs.tweepy.org/en/v4.0.0/index.html).

# %%
# PLEASE FILL IN WITH YOUR OWN API KEYS AND TOKENS!
bearer_token = ""

# %%
# Initialize a Client
client = tweepy.Client(bearer_token)

# %%
query = "Putin -is:retweet"  # The query string
n_tweets = 10  # The maximum number of tweets (default: 10, max: 100)

response = client.search_recent_tweets(
    query,
    max_results=n_tweets
)

tweets = [tweet.text for tweet in response.data]

print('\n\n'.join(tweets))
# Out:
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# <ipython-input-7-83ea22cad8f1> in <cell line: 4>()
#       2 n_tweets = 10  # The maximum number of tweets (default: 10, max: 100)
#       3
# ----> 4 response = client.search_recent_tweets(
#       5     query,
#       6     max_results=n_tweets
#
# /usr/local/lib/python3.10/dist-packages/tweepy/client.py in search_recent_tweets(self, query, user_auth, **params)
#     643         """
#     644         params["query"] = query
# --> 645         return self._make_request(
#     646             "GET", "/2/tweets/search/recent", params=params,
#     647             endpoint_parameters=(
#
# /usr/local/lib/python3.10/dist-packages/tweepy/client.py in _make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     155                 log.warn(f"Unexpected parameter: {param_name}")
#     156
# --> 157         response = self.request(method, route, params=request_params,
#     158                                 json=json, user_auth=user_auth)
#     159
#
# /usr/local/lib/python3.10/dist-packages/tweepy/client.py in request(self, method, route, params, json, user_auth)
#     112                 raise BadRequest(response)
#     113             if response.status_code == 401:
# --> 114                 raise Unauthorized(response)
#     115             if response.status_code == 403:
#     116                 raise Forbidden(response)
#
# Unauthorized: 401 Unauthorized

# %% [markdown]
# ### 2. Pre-processing tweets

# %%
# %%time
tweets_preprocessed = []
for tweet in tweets:
    tweet = tweet.lower()
    tweet = re.sub(r"^https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
    tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
    tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*$", " ", tweet)
    tweet = re.sub(r"that's", "that is", tweet)
    tweet = re.sub(r"there's", "there is", tweet)
    tweet = re.sub(r"what's", "what is", tweet)
    tweet = re.sub(r"where's", "where is", tweet)
    tweet = re.sub(r"it's", "it is", tweet)
    tweet = re.sub(r"who's", "who is", tweet)
    tweet = re.sub(r"i'm", "i am", tweet)
    tweet = re.sub(r"she's", "she is", tweet)
    tweet = re.sub(r"he's", "he is", tweet)
    tweet = re.sub(r"they're", "they are", tweet)
    tweet = re.sub(r"who're", "who are", tweet)
    tweet = re.sub(r"ain't", "am not",tweet)
    tweet = re.sub(r"wouldn't", "would not", tweet)
    tweet = re.sub(r"shouldn't", "should not", tweet)
    tweet = re.sub(r"can't", "can not",tweet)
    tweet = re.sub(r"couldn't", "could not", tweet)
    tweet = re.sub(r"won't", "will not", tweet)
    tweet = re.sub(r"\W", " ", tweet)
    tweet = re.sub(r"\d", " ", tweet)
    tweet = re.sub(r"\s+[a-z]\s+", " ", tweet)
    tweet = re.sub(r"\s+[a-z]$", " ", tweet)
    tweet = re.sub(r"^[a-z]\s+", " ", tweet)
    tweet = re.sub(r"\s+", " ", tweet)
    words = nltk.word_tokenize(tweet)
    words = [x for x in words if x not in stopwords.words('english')]
    tweet = ' '.join(words)
    tweets_preprocessed.append(tweet)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'tweets' is not defined

# %%
# Print out the tweets.
for i, tweet in enumerate(tweets_preprocessed):
    print(f"{i}: {tweet}")

# %% [markdown]
# #### Refactor the code and check for the same results

# %%
def preprocess_tweet(tweet):
    """Preprocess a tweet."""
    tweet = tweet.lower()
    tweet = re.sub(r"^https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
    tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
    tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*$", " ", tweet)
    tweet = re.sub(r"that's", "that is", tweet)
    tweet = re.sub(r"there's", "there is", tweet)
    tweet = re.sub(r"what's", "what is", tweet)
    tweet = re.sub(r"where's", "where is", tweet)
    tweet = re.sub(r"it's", "it is", tweet)
    tweet = re.sub(r"who's", "who is", tweet)
    tweet = re.sub(r"i'm", "i am", tweet)
    tweet = re.sub(r"she's", "she is", tweet)
    tweet = re.sub(r"he's", "he is", tweet)
    tweet = re.sub(r"they're", "they are", tweet)
    tweet = re.sub(r"who're", "who are", tweet)
    tweet = re.sub(r"ain't", "am not",tweet)
    tweet = re.sub(r"wouldn't", "would not", tweet)
    tweet = re.sub(r"shouldn't", "should not", tweet)
    tweet = re.sub(r"can't", "can not",tweet)
    tweet = re.sub(r"couldn't", "could not", tweet)
    tweet = re.sub(r"won't", "will not", tweet)
    tweet = re.sub(r"\W", " ", tweet)
    tweet = re.sub(r"\d", " ", tweet)
    tweet = re.sub(r"\s+[a-z]\s+", " ", tweet)
    tweet = re.sub(r"\s+[a-z]$", " ", tweet)
    tweet = re.sub(r"^[a-z]\s+", " ", tweet)
    tweet = re.sub(r"\s+", " ", tweet)
    words = nltk.word_tokenize(tweet)
    words = [x for x in words if x not in stopwords.words('english')]

    return ' '.join(words)

# %%
# %%time
preprocessed_tweets = map(preprocess_tweet, tweets)

# %%
def print_tweets(tweets):
    """Print tweets."""
    for i, tweet in enumerate(tweets):
        print(f"{i}: {tweet}")

# %%
print_tweets(preprocessed_tweets)

# %% [markdown]
# ### 3. Follow a Twitter user
# More examples can be found [here](hhttps://dev.to/twitterdev/a-comprehensive-guide-for-using-the-twitter-api-v2-using-tweepy-in-python-15d9).

# %%
query = "from:elonmusk -is:retweet"  # Query
n_tweets = 10  # Maximum number of tweets (default: 10, max: 100)

response = client.search_recent_tweets(
    query,
    max_results=n_tweets
)

tweets = [tweet.text for tweet in response.data]

print('\n\n'.join(tweets))

# %%
# %%time
preprocessed_tweets = map(preprocess_tweet, tweets)

# %%
print_tweets(preprocessed_tweets)
