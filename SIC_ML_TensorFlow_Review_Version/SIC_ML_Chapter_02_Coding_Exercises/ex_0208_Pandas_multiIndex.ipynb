# %% [markdown]
# <a href="https://colab.research.google.com/github/tn-220/SIC-Machine-Learning/blob/main/SIC_ML_Coding_Exercises/SIC_ML_Chapter_03_Coding_Exercises/ex_0208.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Coding Exercise #0208

# %% [markdown]
# ### 1. MultiIndex:

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 1.1. Creating a DataFrame with MultiIndex:

# %%
my_header = ['A','B','C']
print(my_header)
# Out:
# ['A', 'B', 'C']

# %%
my_index_out = ['G1']*2 + ['G2']*2 + ['G3']*2
my_index_in = ['a', 'b']*3

print(my_index_out)
print(my_index_in)
# Out:
# ['G1', 'G1', 'G2', 'G2', 'G3', 'G3']
# ['a', 'b', 'a', 'b', 'a', 'b']

# %%
my_index_zipped = list(zip(my_index_out, my_index_in))
my_index_zipped
# Out:
# [('G1', 'a'), ('G1', 'b'), ('G2', 'a'), ('G2', 'b'), ('G3', 'a'), ('G3', 'b')]

# %%
my_multi_index = pd.MultiIndex.from_tuples(my_index_zipped)
print(my_multi_index)

# numpy.random.randn return a sample (or samples) from the “standard normal” distribution.
df = pd.DataFrame(data=np.random.randn(6,3), index=my_multi_index, columns=my_header)
# Out:
# MultiIndex([('G1', 'a'),
#             ('G1', 'b'),
#             ('G2', 'a'),
#             ('G2', 'b'),
#             ('G3', 'a'),
#             ('G3', 'b')],
#            )

# %%
df
# Out:
#              A         B         C
# G1 a  1.397333  0.046053  0.274941
#    b -2.154187 -0.813633  2.010297
# G2 a  1.726162  0.411772  0.898252
#    b -0.619986  0.480988 -0.820114
# G3 a -2.482487  1.287027 -1.116385
#    b  0.103238 -0.782841  1.235810

# %% [markdown]
# #### 1.2. Indexing and slicing DataFrames with MultiIndex:

# %%
df.loc['G1']
# Out:
#           A         B         C
# a  1.397333  0.046053  0.274941
# b -2.154187 -0.813633  2.010297

# %%
# Indexing followed by another indexing.
df.loc['G1'].loc['a']
# Out:
# A    1.397333
# B    0.046053
# C    0.274941
# Name: a, dtype: float64

# %%
# Indexing followed by another indexing.
df.loc['G1'].loc['a','B']
# Out:
# 0.046053076620888124

# %% [markdown]
# ### 2. DataFrame summarization:

# %% [markdown]
# #### 2.1. Group by method:

# %%
# !wget --no-clobber https://raw.githubusercontent.com/tn-220/SIC-Machine-Learning/main/SIC_ML_Coding_Exercises/SIC_ML_Chapter_03_Coding_Exercises/data_studentlist.csv
# Out:
# --2024-06-14 09:53:09--  https://raw.githubusercontent.com/tn-220/SIC-Machine-Learning/main/SIC_ML_Coding_Exercises/SIC_ML_Chapter_03_Coding_Exercises/data_studentlist.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 674 [text/plain]
# Saving to: ‘data_studentlist.csv’
#
# data_studentlist.cs 100%[===================>]     674  --.-KB/s    in 0s
#
# 2024-06-14 09:53:10 (26.9 MB/s) - ‘data_studentlist.csv’ saved [674/674]

# %%
df = pd.read_csv('data_studentlist.csv',header='infer')

# %%
df.head(3)
# Out:
#              name gender  age  grade absence bloodtype  height  weight
# 0   Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1  Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2    Brian Martin      M   24      4       N         B   175.0    80.1

# %%
df['flag_tall'] = np.where(df['height']>= 180, 1, 0)  # Where condition is true it should be first option, otherwise second option
df
# Out:
#                 name gender  age  grade absence bloodtype  height  weight  \
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 16       Andrew King      M   21      1       N         A   169.2    62.2
#
#     flag_tall
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0
# 5           0
# 6           0
# 7           0
# 8           0
# 9           0
# 10          0
# 11          1
# 12          0
# 13          0
# 14          0
# 15          0
# 16          0

# %%
df['flag_tall'] = np.where((df['gender'] == 'M') & (df['height'] >= 180), 1,
                           np.where((df['gender']=='F') & (df['height']>=167), 1, 0))
df
# Out:
#                 name gender  age  grade absence bloodtype  height  weight  \
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 16       Andrew King      M   21      1       N         A   169.2    62.2
#
#     flag_tall
# 0           0
# 1           1
# 2           0
# 3           1
# 4           1
# 5           0
# 6           0
# 7           1
# 8           0
# 9           0
# 10          0
# 11          1
# 12          0
# 13          1
# 14          0
# 15          0
# 16          0

# %%
df2 = df.groupby('gender').mean(numeric_only=True)
df2
# Out:
#               age     grade      height     weight  flag_tall
# gender
# F       21.857143  1.714286  166.642857  50.442857   0.571429
# M       22.700000  2.700000  172.410000  68.500000   0.200000

# %%
df.groupby('gender').mean(numeric_only=True).columns
# Out:
# Index(['age', 'grade', 'height', 'weight', 'flag_tall'], dtype='object')

# %%
df2.index
# Out:
# Index(['F', 'M'], dtype='object', name='gender')

# %%
df2.index.name = None
df2
# Out:
#          age     grade      height     weight  flag_tall
# F  21.857143  1.714286  166.642857  50.442857   0.571429
# M  22.700000  2.700000  172.410000  68.500000   0.200000

# %%
# Operation for one variable
df.groupby('gender')['height'].mean()
# Out:
# gender
# F    166.642857
# M    172.410000
# Name: height, dtype: float64

# %%
# To select more than one variable, you need to put them in a list
df.groupby('gender')[['height','weight']].mean()
# Out:
#             height     weight
# gender
# F       166.642857  50.442857
# M       172.410000  68.500000

# %%
df.groupby('gender')[['grade','age', 'height']].std()
# Out:
#            grade       age    height
# gender
# F       0.755929  1.069045  8.487414
# M       1.159502  1.159502  6.804647

# %%
# agg operator which assigns different methods to the different columns
df3 = df.groupby('gender')[['grade','age', 'height']].agg({'grade':'min', 'age': 'std'})
df3
# Out:
#         grade       age
# gender
# F           1  1.069045
# M           1  1.159502

# %%
df.groupby('gender')['height'].describe()
# Out:
#         count        mean       std    min      25%    50%    75%    max
# gender
# F         7.0  166.642857  8.487414  155.2  160.100  168.0  173.1  176.9
# M        10.0  172.410000  6.804647  162.2  167.475  172.1  177.9  182.1

# %%
# for groupby more than one variable, each variable should be a categorical variable
sr = df.groupby(['gender','bloodtype'])['height'].mean()     # MultiIndexed result.
sr
# Out:
# gender  bloodtype
# F       A            172.450000
#         AB           170.100000
#         B            158.200000
#         O            164.433333
# M       A            165.700000
#         AB           181.050000
#         B            174.550000
#         O            166.200000
# Name: height, dtype: float64

# %%
sr.index.names = [None, None]
sr
# Out:
# F  A     172.450000
#    AB    170.100000
#    B     158.200000
#    O     164.433333
# M  A     165.700000
#    AB    181.050000
#    B     174.550000
#    O     166.200000
# Name: height, dtype: float64

# %%
sr.loc['F']
# Out:
# A     172.450000
# AB    170.100000
# B     158.200000
# O     164.433333
# Name: height, dtype: float64

# %%
sr.loc['F'].loc['A']
# Out:
# 172.45

# %% [markdown]
# #### 2.2.  DataFrame methods:

# %%
df['height'].apply(lambda x: x/100)
# Out:
# 0     1.653
# 1     1.701
# 2     1.750
# 3     1.821
# 4     1.680
# 5     1.620
# 6     1.552
# 7     1.769
# 8     1.785
# 9     1.761
# 10    1.671
# 11    1.800
# 12    1.622
# 13    1.761
# 14    1.582
# 15    1.686
# 16    1.692
# Name: height, dtype: float64

# %%
df.sort_values(by='bloodtype')
# Out:
#                 name gender  age  grade absence bloodtype  height  weight  \
# 16       Andrew King      M   21      1       N         A   169.2    62.2
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
#
#     flag_tall
# 16          0
# 4           1
# 12          0
# 7           1
# 1           1
# 3           1
# 11          1
# 14          0
# 9           0
# 8           0
# 2           0
# 15          0
# 10          0
# 6           0
# 5           0
# 13          1
# 0           0

# %%
df.sort_values(by='bloodtype', ascending=False)
# Out:
#                 name gender  age  grade absence bloodtype  height  weight  \
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 16       Andrew King      M   21      1       N         A   169.2    62.2
#
#     flag_tall
# 0           0
# 13          1
# 5           0
# 6           0
# 10          0
# 9           0
# 15          0
# 14          0
# 8           0
# 2           0
# 1           1
# 11          1
# 3           1
# 7           1
# 12          0
# 4           1
# 16          0

# %%
df.sort_values(by=['bloodtype','gender'])
# Out:
#                 name gender  age  grade absence bloodtype  height  weight  \
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 16       Andrew King      M   21      1       N         A   169.2    62.2
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
#
#     flag_tall
# 4           1
# 7           1
# 12          0
# 16          0
# 1           1
# 3           1
# 11          1
# 14          0
# 2           0
# 8           0
# 9           0
# 15          0
# 5           0
# 6           0
# 13          1
# 0           0
# 10          0

# %%
df['bloodtype'].unique()
# Out:
# array(['O', 'AB', 'B', 'A'], dtype=object)

# %%
df['bloodtype'].nunique()
# Out:
# 4

# %%
# Frequency table.
df['bloodtype'].value_counts()
# Out:
# bloodtype
# O     5
# B     5
# A     4
# AB    3
# Name: count, dtype: int64

# %%
# Frequency table.
df['gender'].value_counts()
# Out:
# gender
# M    10
# F     7
# Name: count, dtype: int64

# %% [markdown]
# #### 2.3. Pivoting:

# %%
my_dict = {"Size": ["L", "L", "M", "M", "M", "S", "S", "S", "S"],
           "Type": ["A", "A", "A", "B", "B", "A", "A", "B", "B"],
            "Location": ["L1", "L1", "L1", "L2", "L2", "L1", "L2", "L2", "L1"],
            "A": [1, 2, 2, 3, 3, 4, 5, 6, 7],
            "B": [2, 4, 5, 5, 6, 6, 8, 9, 9]}
df = pd.DataFrame(my_dict)
df
# Out:
#   Size Type Location  A  B
# 0    L    A       L1  1  2
# 1    L    A       L1  2  4
# 2    M    A       L1  2  5
# 3    M    B       L2  3  5
# 4    M    B       L2  3  6
# 5    S    A       L1  4  6
# 6    S    A       L2  5  8
# 7    S    B       L2  6  9
# 8    S    B       L1  7  9

# %%
# Index by 'Size' and 'Type'. Columns by 'Location'. Values provided by the 'B' column.
dfr = pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B')
dfr
# Out:
# Location    L1   L2
# Size Type
# L    A     3.0  NaN
# M    A     5.0  NaN
#      B     NaN  5.5
# S    A     6.0  8.0
#      B     9.0  9.0

# %%
print(dfr.columns.name)
print(dfr.columns)
print(dfr)
# Out:
# Location
# Index(['L1', 'L2'], dtype='object', name='Location')
# Location    L1   L2
# Size Type
# L    A     3.0  NaN
# M    A     5.0  NaN
#      B     NaN  5.5
# S    A     6.0  8.0
#      B     9.0  9.0

# %%
dfr.columns
# Out:
# Index(['L1', 'L2'], dtype='object', name='Location')

# %%
dfr.index                                                                 # MultiIndex object!
# Out:
# MultiIndex([('L', 'A'),
#             ('M', 'A'),
#             ('M', 'B'),
#             ('S', 'A'),
#             ('S', 'B')],
#            names=['Size', 'Type'])

# %%
# The same as above, but fill the missing values with 0.
pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B', fill_value=0)
# Out:
# Location   L1   L2
# Size Type
# L    A      3  0.0
# M    A      5  0.0
#      B      0  5.5
# S    A      6  8.0
#      B      9  9.0

# %%
# The same as above with the aggregation function specified.
pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B', aggfunc = np.mean, fill_value=0)
# Out:
# Location   L1   L2
# Size Type
# L    A      3  0.0
# M    A      5  0.0
#      B      0  5.5
# S    A      6  8.0
#      B      9  9.0

# %%
# Index by ''Location'. Columns by 'Size' and 'Type'. Values provided by the 'B' column.
dfr = pd.pivot_table(df, index='Location', columns=['Size','Type'], values='B')
dfr
# Out:
# Size        L    M         S
# Type        A    A    B    A    B
# Location
# L1        3.0  5.0  NaN  6.0  9.0
# L2        NaN  NaN  5.5  8.0  9.0

# %%
dfr.index
# Out:
# Index(['L1', 'L2'], dtype='object', name='Location')

# %%
dfr.columns                                                           # Now, MultiIndex object for the columns.
# Out:
# MultiIndex([('L', 'A'),
#             ('M', 'A'),
#             ('M', 'B'),
#             ('S', 'A'),
#             ('S', 'B')],
#            names=['Size', 'Type'])

# %%
# The aggregation funciton is numpy.median().
pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B', aggfunc = np.median, fill_value=0)
# Out:
# Location   L1   L2
# Size Type
# L    A      3  0.0
# M    A      5  0.0
#      B      0  5.5
# S    A      6  8.0
#      B      9  9.0

# %%
# Group averages of the columns 'A' and 'B'.
pd.pivot_table(df, index=['Size','Type'], values=['A','B'], aggfunc=np.mean)
# Out:
#              A    B
# Size Type
# L    A     1.5  3.0
# M    A     2.0  5.0
#      B     3.0  5.5
# S    A     4.5  7.0
#      B     6.5  9.0

# %%
# Now, with groupby() method.
# The result is the same.
df.groupby(['Size','Type'])[['A','B']].mean()
# Out:
#              A    B
# Size Type
# L    A     1.5  3.0
# M    A     2.0  5.0
#      B     3.0  5.5
# S    A     4.5  7.0
#      B     6.5  9.0

# %%
# Aggregate differenly the columns 'A' and 'B'.
pd.pivot_table(df, index=['Size','Type'], values=['A','B'], aggfunc={'A':np.max,'B':np.min})
# Out:
#            A  B
# Size Type
# L    A     2  2
# M    A     2  5
#      B     3  5
# S    A     5  6
#      B     7  9
