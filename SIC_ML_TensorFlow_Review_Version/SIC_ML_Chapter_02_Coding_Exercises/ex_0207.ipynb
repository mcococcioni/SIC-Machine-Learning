# %% [markdown]
# <a href="https://colab.research.google.com/github/tn-220/SIC-Machine-Learning/blob/main/SIC_ML_Coding_Exercises/SIC_ML_Chapter_03_Coding_Exercises/ex_0207.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Coding Exercise #0207

# %% [markdown]
# ### 1. Statistics with Pandas:

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 1.1. Read data into a DataFrame:
#
# (Type of a variable can be categorical, discrete numerical, and continuous numeric)

# %%
# !wget --no-clobber https://raw.githubusercontent.com/tn-220/SIC-Machine-Learning/main/SIC_ML_Coding_Exercises/SIC_ML_Chapter_03_Coding_Exercises/data_iris.csv
# Out:
# --2024-06-14 09:41:30--  https://raw.githubusercontent.com/tn-220/SIC-Machine-Learning/main/SIC_ML_Coding_Exercises/SIC_ML_Chapter_03_Coding_Exercises/data_iris.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3867 (3.8K) [text/plain]
# Saving to: ‘data_iris.csv’
#
# data_iris.csv       100%[===================>]   3.78K  --.-KB/s    in 0s
#
# 2024-06-14 09:41:30 (49.0 MB/s) - ‘data_iris.csv’ saved [3867/3867]

# %%
df = pd.read_csv('data_iris.csv', header='infer')

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
df.tail(3)
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# #### 1.2. Statistics using DataFrame methods:

# %%
# Column averages.
df.mean(axis=0, numeric_only=True)
# Out:
# Sepal.Length    5.843333
# Sepal.Width     3.057333
# Petal.Length    3.758000
# Petal.Width     1.199333
# dtype: float64

# %%
# Descriptive statistics.
df.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Correlation.
df.loc[:,'Sepal.Length'].corr(df.loc[:,'Sepal.Width'])
# Out:
# -0.11756978413300208

# %%
# Correlation.
df.loc[:,'Sepal.Length'].corr(df.loc[:,'Petal.Length'])
# Out:
# 0.8717537758865831

# %%
# Correlation matrix.
np.round(df.corr(numeric_only=True),3)
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length         1.000       -0.118         0.872        0.818
# Sepal.Width         -0.118        1.000        -0.428       -0.366
# Petal.Length         0.872       -0.428         1.000        0.963
# Petal.Width          0.818       -0.366         0.963        1.000

# %%
# Correlation with respect to one variable (column).
df.corrwith(df.loc[:,'Petal.Length'], numeric_only=True)
# Out:
# Sepal.Length    0.871754
# Sepal.Width    -0.428440
# Petal.Length    1.000000
# Petal.Width     0.962865
# dtype: float64

# %% [markdown]
# #### 1.3. Slice and then apply a statistic method:

# %%
df[df.Species=='setosa'].mean(axis=0, numeric_only=True)
# Out:
# Sepal.Length    5.006
# Sepal.Width     3.428
# Petal.Length    1.462
# Petal.Width     0.246
# dtype: float64

# %%
df[df.Species=='virginica'].mean(axis=0, numeric_only=True)
# Out:
# Sepal.Length    6.588
# Sepal.Width     2.974
# Petal.Length    5.552
# Petal.Width     2.026
# dtype: float64

# %%
df[df.Species=='versicolor'].mean(axis=0, numeric_only=True)
# Out:
# Sepal.Length    5.936
# Sepal.Width     2.770
# Petal.Length    4.260
# Petal.Width     1.326
# dtype: float64

# %% [markdown]
# Frequency table:

# %%
df.Species.value_counts()
# Out:
# Species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ### 2. Missing values:
# (When you have a missing value, it is common to replace it with mean of data)

# %% [markdown]
# First of all, we purposefully enter the missing values:

# %%
df.iloc[10,0] = np.nan
df.iloc[2,2] = np.nan
df.iloc[17,2] = np.nan
df.iloc[2,3] = np.nan
df.iloc[129,2] = np.nan

# %%
df.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           NaN          NaN  setosa

# %% [markdown]
# #### 2.1. Statistics of the missing values:

# %%
# Count non-missing values per column.
df.count(axis=0)
# Out:
# Sepal.Length    149
# Sepal.Width     150
# Petal.Length    147
# Petal.Width     149
# Species         150
# dtype: int64

# %%
df['Petal.Length'].count()
# Out:
# 147

# %%
# Calculate the averages skipping the missing values.
df.drop(columns='Species').mean(axis=0)                                 # 'Species' column is left out.
# Out:
# Sepal.Length    5.846309
# Sepal.Width     3.057333
# Petal.Length    3.776871
# Petal.Width     1.206040
# dtype: float64

# %%
# Try to calculate the averages without skipping the missing values.  => NaNs appear!
df.drop(columns='Species').mean(axis=0, skipna=False)                  # 'Species' column is left out.
# Out:
# Sepal.Length         NaN
# Sepal.Width     3.057333
# Petal.Length         NaN
# Petal.Width          NaN
# dtype: float64

# %% [markdown]
# #### 2.2. Detect and process the missing values:

# %%
# Count the missing values per column.
(df.isnull()).sum(axis=0)
# Out:
# Sepal.Length    1
# Sepal.Width     0
# Petal.Length    3
# Petal.Width     1
# Species         0
# dtype: int64

# %%
(df.notnull()).sum(axis=0)
# Out:
# Sepal.Length    149
# Sepal.Width     150
# Petal.Length    147
# Petal.Width     149
# Species         150
# dtype: int64

# %%
1/150
3/150
# Out:
# 0.02

# %%
# Proportion of missing values per column.
(df.isnull()).mean(axis=0)
# Out:
# Sepal.Length    0.006667
# Sepal.Width     0.000000
# Petal.Length    0.020000
# Petal.Width     0.006667
# Species         0.000000
# dtype: float64

# %%
# Drop the rows with at least one missing value.
df2 = df.dropna(axis=0)

# %%
df2.shape
# Out:
# (146, 5)

# %%
df2.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa

# %%
# Drop the rows with less than 4 normal values.
df2 = df.dropna(axis=0, thresh = 4)
df2.shape
# Out:
# (149, 5)

# %%
# Drop the columns with at least one missing value.
df3 = df.dropna(axis=1)
df3.shape
# Out:
# (150, 2)

# %%
df3.head(3)
# Out:
#    Sepal.Width Species
# 0          3.5  setosa
# 1          3.0  setosa
# 2          3.2  setosa

# %%
# Drop the columns with less than 149 normal values.
df3 = df.dropna(axis=1, thresh = 149)
df3.shape
# Out:
# (150, 4)

# %%
df3.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Width Species
# 0           5.1          3.5          0.2  setosa
# 1           4.9          3.0          0.2  setosa
# 2           4.7          3.2          NaN  setosa

# %% [markdown]
# #### 2.3. Fill the missing values:

# %%
# Fill the missing values with 0.
df4 = df.fillna(value=0)
df4.count()                         # axis=0 by default.
# Out:
# Sepal.Length    150
# Sepal.Width     150
# Petal.Length    150
# Petal.Width     150
# Species         150
# dtype: int64

# %%
# Fill the missing values using column averages.
df['Sepal.Length'] = df['Sepal.Length'].fillna(value=df['Sepal.Length'].mean())
df['Petal.Length'] = df['Petal.Length'].fillna(value=df['Petal.Length'].mean())
df['Petal.Width'] = df['Petal.Width'].fillna(value=df['Petal.Width'].mean())
df.count()                          # axis=0 by default.
# Out:
# Sepal.Length    150
# Sepal.Width     150
# Petal.Length    150
# Petal.Width     150
# Species         150
# dtype: int64

# %%
df.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5      1.400000      0.20000  setosa
# 1           4.9          3.0      1.400000      0.20000  setosa
# 2           4.7          3.2      3.776871      1.20604  setosa
