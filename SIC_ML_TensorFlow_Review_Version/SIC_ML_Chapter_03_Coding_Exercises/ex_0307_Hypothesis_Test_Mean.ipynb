# %% [markdown]
# <a href="https://colab.research.google.com/github/tn-220/SIC-Machine-Learning/blob/main/SIC_ML_Coding_Exercises/SIC_ML_Chapter_04_Coding_Exercises/ex_0307.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Coding Exercise #0307

# %% [markdown]
# ### 1. Correlation:

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import os

# %%
# !wget --no-clobber https://raw.githubusercontent.com/tn-220/SIC-Machine-Learning/main/SIC_ML_Coding_Exercises/SIC_ML_Chapter_04_Coding_Exercises/data_iris.csv
# Out:
# --2024-06-14 11:12:47--  https://raw.githubusercontent.com/tn-220/SIC-Machine-Learning/main/SIC_ML_Coding_Exercises/SIC_ML_Chapter_04_Coding_Exercises/data_iris.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3867 (3.8K) [text/plain]
# Saving to: ‘data_iris.csv’
#
# data_iris.csv       100%[===================>]   3.78K  --.-KB/s    in 0s
#
# 2024-06-14 11:12:47 (48.3 MB/s) - ‘data_iris.csv’ saved [3867/3867]

# %%
# Read in the data.
df = pd.read_csv('data_iris.csv', header='infer')

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
# Set aside two variables.
x = df['Petal.Length']
y = df['Sepal.Length']

# %% [markdown]
# #### 1.1. Pearson:

# %%
# Using the SciPy function.
# Correlation and p-value.
np.round(st.pearsonr(x,y, alternative='two-sided'),3)      # Pearson correlation coefficient and p-value for testing non-correlation.

"""
    An object with the following attributes:
       - Pearson product-moment correlation coefficent.
       - The p-value associated with the chosen alternative.
"""
# Out:
# '\n    An object with the following attributes:\n       - Pearson product-moment correlation coefficent.\n       - The p-value associated with the chosen alternative.\n'

# %%
# Using the Pandas function.
x.corr(y)
# Out:
# 0.8717537758865831

# %%
# Correlation array.
np.round(df.corr(numeric_only=True),3)
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length         1.000       -0.118         0.872        0.818
# Sepal.Width         -0.118        1.000        -0.428       -0.366
# Petal.Length         0.872       -0.428         1.000        0.963
# Petal.Width          0.818       -0.366         0.963        1.000

# %% [markdown]
# #### 1.2. Spearman:

# %%
# Using the SciPy function.
# Correlation and p-value.
np.round(st.spearmanr(x,y),3)
# Out:
# array([0.882, 0.   ])

# %% [markdown]
# #### 1.3. Kendall:

# %%
# Using the SciPy function.
# Correlation and p-value.
np.round(st.kendalltau(x,y),3)         # 상관계수와 p-값.
# Out:
# array([0.719, 0.   ])

# %% [markdown]
# ### 2. Interval Estimation of the Correlation:

# %%
# !wget --no-clobber https://raw.githubusercontent.com/tn-220/SIC-Machine-Learning/main/SIC_ML_Coding_Exercises/SIC_ML_Chapter_04_Coding_Exercises/data_studentlist.csv
# Out:
# --2024-06-14 11:12:47--  https://raw.githubusercontent.com/tn-220/SIC-Machine-Learning/main/SIC_ML_Coding_Exercises/SIC_ML_Chapter_04_Coding_Exercises/data_studentlist.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 674 [text/plain]
# Saving to: ‘data_studentlist.csv’
#
# data_studentlist.cs 100%[===================>]     674  --.-KB/s    in 0s
#
# 2024-06-14 11:12:47 (33.1 MB/s) - ‘data_studentlist.csv’ saved [674/674]

# %%
# Read in another data set.
df = pd.read_csv('data_studentlist.csv', header='infer')

# %%
df.head(3)
# Out:
#              name gender  age  grade absence bloodtype  height  weight
# 0   Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1  Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2    Brian Martin      M   24      4       N         B   175.0    80.1

# %%
# Set aside two variables.
x = df.height
y = df.weight

# %% [markdown]
# #### 2.2. Confidence Interval of the Pearson Correlation:

# %%
# Apply the Fisher's z-transformation.
# See the lecture.
n = len(x)
r = x.corr(y)
z = np.arctanh(r)
std_error_z = 1/np.sqrt(n-3)

# %%
# 95% confidence interval.
# Expressed as a dictionary object.
{'low':np.tanh(z-st.norm.ppf(0.975)*std_error_z), 'high': np.tanh(z+st.norm.ppf(0.975)*std_error_z)}
# Out:
# {'low': 0.26960396330592223, 'high': 0.8677953581441814}

# %%
# 99% confidence interval.
# Expressed as a dictionary object.
{'low':np.tanh(z-st.norm.ppf(0.995)*std_error_z), 'high': np.tanh(z+st.norm.ppf(0.995)*std_error_z)}
# Out:
# {'low': 0.11137578298592947, 'high': 0.9030812794020874}
